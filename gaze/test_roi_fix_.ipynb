# %%
import numpy as np

# %%
data = np.load('./gaze/ROI/roiLook010.asc.npy',allow_pickle=True)

# %%
data[0]['fixations'][0]
# Out:
# {'type': 'fixation',
#  'mean': array([950.71515152, 508.50505051]),
#  'roi': 'eyes'}

# %%
for index,trial in enumerate(data):
    sacc_list = trial['saccades']
    print('trial: '+str(index)+'  sac len: '+str(len(sacc_list)))

    fix_list = trial['fixations']
    print('trial: '+str(index)+'  fix len: '+str(len(fix_list)))
# Out:
# trial: 0  sac len: 16
# trial: 0  fix len: 23
# trial: 1  sac len: 21
# trial: 1  fix len: 32
# trial: 2  sac len: 15
# trial: 2  fix len: 19
# trial: 3  sac len: 14
# trial: 3  fix len: 16
# trial: 4  sac len: 9
# trial: 4  fix len: 13
# trial: 5  sac len: 14
# trial: 5  fix len: 18
# trial: 6  sac len: 13
# trial: 6  fix len: 18
# trial: 7  sac len: 18
# trial: 7  fix len: 26
# trial: 8  sac len: 18
# trial: 8  fix len: 23
# trial: 9  sac len: 16
# trial: 9  fix len: 22
# trial: 10  sac len: 15
# trial: 10  fix len: 21
# trial: 11  sac len: 14
# trial: 11  fix len: 17
# trial: 12  sac len: 12
# trial: 12  fix len: 13
# trial: 13  sac len: 12
# trial: 13  fix len: 13
# trial: 14  sac len: 17
# trial: 14  fix len: 26
# trial: 15  sac len: 11
# trial: 15  fix len: 14
# trial: 16  sac len: 17
# trial: 16  fix len: 21
# trial: 17  sac len: 22
# trial: 17  fix len: 32
# trial: 18  sac len: 20
# trial: 18  fix len: 23
# trial: 19  sac len: 19
# trial: 19  fix len: 26
# ...

# %%
data2 = np.load('../gaze_fear_generalization-main/features/Reutter_OU_posterior_VI/train/event_features_10.npy',allow_pickle=True)
data2

# %%
for index,trial in enumerate(data2):
    sacc_list = trial['sacc_fix']
    print('trial: '+str(index)+'  len sac: '+str(len(sacc_list)))

    fix_list = trial['feat_fix']
    print('trial: '+str(index)+'  len fix: '+str(len(fix_list)))
# Out:
# trial: 0  len sac: 16
# trial: 0  len fix: 23
# trial: 1  len sac: 21
# trial: 1  len fix: 32
# trial: 2  len sac: 15
# trial: 2  len fix: 19
# trial: 3  len sac: 14
# trial: 3  len fix: 16
# trial: 4  len sac: 9
# trial: 4  len fix: 13
# trial: 5  len sac: 14
# trial: 5  len fix: 18
# trial: 6  len sac: 13
# trial: 6  len fix: 18
# trial: 7  len sac: 18
# trial: 7  len fix: 26
# trial: 8  len sac: 18
# trial: 8  len fix: 23
# trial: 9  len sac: 16
# trial: 9  len fix: 22
# trial: 10  len sac: 15
# trial: 10  len fix: 21
# trial: 11  len sac: 14
# trial: 11  len fix: 17
# trial: 12  len sac: 12
# trial: 12  len fix: 13
# trial: 13  len sac: 12
# trial: 13  len fix: 13
# trial: 14  len sac: 17
# trial: 14  len fix: 26
# trial: 15  len sac: 11
# trial: 15  len fix: 14
# trial: 16  len sac: 17
# trial: 16  len fix: 21
# trial: 17  len sac: 22
# trial: 17  len fix: 32
# trial: 18  len sac: 20
# trial: 18  len fix: 23
# trial: 19  len sac: 19
# trial: 19  len fix: 26
# ...
